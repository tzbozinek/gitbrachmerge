# %%
import numpy as np
import pandas as pd

import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()

# %%
x = np.linspace(0,4)
y = np.sin(x)

# %%
p1 = bokeh.plotting.figure(width = 450, height = 350)
p1.line(x,y, line_width = 2)
bokeh.io.show(p1)
# Out:
#   <div class="bk-root" id="5d908ce9-5878-43c8-871d-59d7ae135a5f" data-root-id="1001"></div>

# %%
p2 = bokeh.plotting.figure(width = 450, height = 350)
p2.line(y,x, line_width = 2)
bokeh.io.show(p2)
# Out:
#   <div class="bk-root" id="00178b54-4b65-4fd8-a3d4-13aa70e1e4f1" data-root-id="1100"></div>

# %%
print('okay')
# Out:
# okay
